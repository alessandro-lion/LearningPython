# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandro-lion/LearningPython/blob/main/Script_costruzione_where_clause_nome_per_update_informazione_sesso_su_db_anagrafiche_con_ricerca_su_wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googlesearch import search
import requests
nomiverificabili=['IONA',
'LIBORIA',
'BARNABA',
'BRANCALEONE',
'CELINIA',
'BABILA',
'NARSETE',
'GIOSUELE',
'DEODATA',
'UMILE',
'DODA',
'EURIDICE',
'ERSILIA',
'CUZIA',
'ELITA',
'ASELLA',
'INNOCENTE',
'VENUSTA',
'CLEOFE',
'AMABILE',
'VALTENA',
'ELIMENA',
'SALOMÈ',
'GEDEONE',
'DANTE',
'GEREMIA',
'CARONTE',
'AGENORE',
'PARIDE',
'IACOPONE',
'POLISSENA',
'ELVIA',
'GIONATA',
'TICONE',
'ZAIRA',
'ASTRID',
'BICE',
'MARANA',
'ABELE',
'COSMA',
'FEDELE',
'LUIGIA',
'ADELAIDE',
'AMATORE',
'ZENOBIA',
'ZACCARIA',
'IDEA',
'ARIELE',
'NICLA',
'VIRONE',
'ERENIA',
'ERACLIDE',
'ISOTTA',
'SEFORA',
'TAZIANA',
'BELINA',
'NICARETE',
'ERACLA',
'VITALE',
'DIONIGI',
'VALENTE',
'NEREA',
'SECONDINA',
'CUNEGONDA',
'MELCHIADE',
'TEOGENE',
'AMOS',
'TRASEA',
'LEONE',
'ADRIA',
'ALCIBIADE',
'DORA',
'LILIANA',
'DESDEMONA',
'OSCAR',
'ZELINDA',
'TECLA',
'NICEA',
'CORA',
'BAMBINA',
'ISIDORA',
'NUCCIA',
'SAPIENTE',
'OMAR',
'PERICLE',
'MANUELE',
'QUITERIA',
'OSANNA',
'GIOELE',
'DELINDA',
'MENNONE',
'GENTILE',
'MAMANTE',
'GOLIA',
'ONORINA',
'SCOLASTICA',
'DONNA',
'ASTIANATTE',
'DALIDA',
'AMILCARE',
'VITTORE',
'ODDONE',
'BONAVITA',
'ILENIA',
'DIAMANTE',
'FLORA',
'URIELE',
'RINA',
'IDA',
'POLLIONE',
'VERIANA',
'DAVIDE',
'ENRICA',
'VIRGINIA',
'ORNELLA',
'ARMIDA',
'BALDASSARRE',
'GASPARE',
'PAOLA',
'AUDACE',
'LICIA',
'PRISCA',
'EDDA',
'LORIS',
'GAUDENZIA',
'CINZIA',
'CELESTE',
'TELICA',
'GUNDELINDA',
'COLOMBA',
'AMORE',
'MORGANA',
'LIA',
'ORSOLA',
'LUCREZIA',
'FABIANA',
'EGEA',
'EGIZIA',
'APOLLINA',
'CLEOPATRA',
'PERLA',
'BERENICE',
'MASSIMA',
'GLENDA',
'AIDA',
'ANTEA',
'GENESIA',
'VALTER',
'ERCOLE',
'MACARIA',
'SALOMONE',
'AMINA',
'BATTISTA',
'ABBONDANZA',
'LELIA',
'ARABELLA',
'ZENONE',
'RUFINA',
'ILEANA',
'AZELIA',
'ARTEMISA',
'LUISA',
'BARTOLOMEA',
'VIDONE',
'ENEA',
'ANNA',
'DINA',
'AMELIA',
'BORIS',
'ACHILLE',
'APPIA',
'EDITTA',
'ILVA',
'SANTINA',
'ROSAMUNDA',
'GIULIA',
'GIAMBATTISTA',
'INES',
'GIUDITTA',
'LORETTA',
'SAMANTA',
'CALPURNIA',
'ARIANNA',
'ESTELLA',
'GODEBERTA',
'EULALIA',
'MANUELA',
'SOSTENE',
'BEATA',
'VISSIA',
'LEDA',
'GASTONE',
'ANATOLIA',
'ROMOLA',
'ATHOS',
'DAMOCLE',
'CLAUDIA',
'DELFINA',
'ILDA',
'ELISABETTA',
'MELITINA',
'AMAURI',
'CLEMENZIA',
'ZANITA',
'NOVELLA',
'MELANIA',
'MARA',
'MARITA',
'IMELDA',
'QUARTILLA',
'FLAMINIA',
'EDVIGE',
'GIULIANA',
'SOFIA',
'PRISCILLA',
'EMILIA',
'DURANTE',
'ROBERTA',
'LAVINIA',
'VILIANA',
'ANNUNZIATA',
'CALOGERA',
'GIANLUIGI',
'ANNABELLA',
'SERAPIONE',
'GIUSEPPE',
'LUCIANA',
'BENEDETTA',
'FAUSTA',
'DONATELLA',
'PATRIZIA',
'CAMILLA',
'PLACIDA',
'AZZURRA',
'ARCHIMEDE',
'ANASTASIA',
'ZOE',
'FEDORA',
'ARISTIDE',
'NEIVA',
'ELISEA',
'CORDELIA',
'ELAIDE',
'ELIDE',
'ARMAND',
'NINA',
'DOROTEA',
'MARUTA',
'SABRINA',
'BONAVENTURA',
'PIERLUIGI',
'DEMETRIA',
'ZARINA',
'IMMACOLATA',
'AGAPE',
'FRANCA',
'CRISTINA',
'IVANOE',
'DANIELA',
'AVE',
'TIRONE',
'NICOLA',
'IVETTA',
'CORINNA',
'ALCINA',
'AGAMENNONE',
'GIOVANNI',
'MARIANNA',
'CATERINA',
'CHIARA',
'BASSILLA',
'BRIGIDA',
'GILIOLA',
'ANDREA',
'MADDALENA',
'LEONIDA',
'BONAGIUNTA',
'RAFFAELE',
'GIANMARIA',
'BENIGNA',
'MIRTA',
'SVEVA',
'SOCRATE',
'FELICITA',
'MONITORE',
'LORENA',
'VENERANDA',
'ITALIA',
'CRISTIANA',
'NADIA',
'CORNELIA',
'ELETTRA',
'MARINA',
'ILIA',
'ISABELLA',
'GRETA',
'OTILIA',
'GABRIELE',
'BRUNILDE',
'GERTRUDE',
'LUCILLA',
'ALDA',
'BASILIA',
'VERA',
'ELVIRA',
'GIANBATTISTA',
'ADINA',
'AGNESE',
'ADONE',
'FLORINA',
'LORENZA',
'EBE',
'DIONISIA',
'SANTE',
'CARLA',
'ALBINA',
'GHITA',
'OFELIA',
'ISIDE',
'TARSILLA',
'AURORA',
'CATENA',
'TESIFONTE',
'CLOE',
'DONATA',
'ELISA',
'DRUINA',
'MARTA',
'ARATONE',
'REBECCA',
'DEBORA',
'GIOSUÈ',
'GIOACCHINA',
'EGLE',
'SALVATORE',
'CASSIOPEA',
'ELIA',
'GIACOBBE',
'NIVES',
'ROSALINDA',
'ALBERTA',
'ARONNE',
'ROSALIA',
'SELENE',
'EUFEMIA',
'GIOVANNA',
'PLATONE',
'ADRIANA',
'LUNA',
'BATILDA',
'SIMONETTA',
'APOLLINARE',
'DIONE',
'BRIGITTA',
'LUIGI',
'LINDA',
'TEA',
'NORMA',
'ERMETE',
'SOLANGE',
'OLIVIERA',
'PAMELA',
'LEONTINA',
'SIMEONE',
'GIORGIA',
'GISELLA',
'EMILIANA',
'GIONA',
'VILMA',
'ALTEA',
'EUCLIDE',
'DOMENICA',
'MARZIA',
'EZECHIELE',
'TURI',
'FIAMMETTA',
'ADRIONE',
'SEMIRAMIDE',
'CLEMENTE',
'ALESSIA',
'UGUCCIONE',
'ADELE',
'VIVIANA',
'ALCESTE',
'RENATA',
'LODOVICA',
'GERMANA',
'ORSOLINA',
'TULLIA',
'ESAÙ',
'AMONE',
'SIDONIA',
'EMANUELE',
'TOSCA',
'SENOFONTE',
'ORCHIDEA',
'ADALBERTA',
'MILENA',
'SARA',
'ISAIA',
'FATIMA',
'GIOVE',
'GODIVA',
'ULFA',
'MARINELLA',
'MARETA',
'LAURA',
'UGOLINA',
'IRENE',
'FOSCA',
'CAROLINA',
'CASILDA',
'APOLLONIA',
'ALMA',
'DAMIANA',
'MATILDE',
'ZENA',
'FLAVIA',
'GIUDA',
'DELIZIA',
'ELEONORA',
'ROMINA',
'GENEROSA',
'WALTER',
'AIMONE',
'SAMUELE',
'CARMINE',
'ANGELA',
'NAPOLEONE',
'DIOGENE',
'NILDE',
'ROSMUNDA',
'ERMES',
'ELIANA',
'VANESSA',
'VANNA',
'NOÈ',
'CARLOTTA',
'NATALIA',
'GONZAGA',
'IOLANDA',
'ANTONELLA',
'CLARA',
'SUSANNA',
'CARMELA',
'TERESA',
'EMANUELA',
'GRAZIA',
'DANIELE',
'VANDA',
'LEONILDA',
'TEMISTOCLE',
'ADELINA',
'DARIA',
'GUENDALINA',
'LUCA',
'TEODORA',
'FIORENZA',
'AMATA',
'AGRIPPA',
'CIRILLA',
'LIDANIA',
'IRMINA',
'BIBIANA',
'COINTA',
'MATTIA',
'VIOLA',
'ERMINIA',
'SAMONA',
'NOEMI',
'BARSABA',
'VENTURA',
'FULVIA',
'ONESTA',
'DILETTA',
'IVONE',
'MINERVINA',
'GIANLUCA',
'DOLORES',
'TEODATA',
'ARISTOFANE',
'PANTALEONE',
'DIANORA',
'DIANA',
'ADELASIA',
'LIVIANA',
'SEVERA',
'ROSITA',
'LISA',
'PROSERPINA',
'GUENDA',
'AUSILIA',
'ARIS',
'MENODORA',
'ULISSE',
'NUNZIATA',
'CASIMIRA',
'COSTANZA',
'FILOMENA',
'ADELCHI',
'MAIDA',
'ONDINA',
'GAIA',
'DIODATA',
'EVANGELINA',
'CARINA',
'ROSA',
'EUSEBIA',
'GIGLIOLA',
'GALATEA',
'SILVANA',
'AUSILIATRICE',
'ALFONSA',
'SERAFINA',
'AMINTORE',
'VERDIANA',
'FIORELLA',
'FIORE',
'LUCE',
'PALMIRA',
'NINFA',
'ISCHIRIONE',
'LARA',
'LIBERATORE',
'COSTANTE',
'PALLADIA',
'ISA',
'DALILA',
'ERMENEGILDA',
'SIBILLA',
'AURELIA',
'NESTORE',
'GRAZIELLA',
'TOBIA',
'ATANASIA',
'ANNIBALE',
'NATALINA',
'FLORIANA',
'NORINA',
'PELAGIA',
'ELOISA',
'OTTONE',
'SANDRA',
'CRONIDA',
'DAFNE',
'LEONIA',
'LUCIA',
'QUIETA',
'VERIDIANA',
'VERONICA',
'SOLOCONE',
'PROSPERA',
'TIZIANA',
'CAMELIA',
'GELSOMINA',
'LIANA',
'DEGNA',
'ZABINA',
'ASSUNTA',
'ALICE',
'SABINA',
'ARGELIA',
'MAURA',
'ELSA',
'RICCARDA',
'MORENA',
'PENELOPE',
'MERCEDE',
'AZA',
'MINERVA',
'MARTINA',
'AGATA',
'DEANNA',
'ANTONIA',
'INNOCENZA',
'GINEVRA',
'MARIA',
'LUDOVICA',
'NATALE',
'IPPOCRATE',
'AGOSTINA',
'ARISTIONE',
'ULIVA',
'MOSÈ',
'ANDROMEDA',
'MARISA',
'CRESCENTE',
'IGINIA',
'AIACE',
'ALESSANDRA',
'ZAMA',
'DEMOSTENE',
'GIOBBE',
'MIRANDA',
'GIACINTA',
'SOAVE',
'EVELINA',
];
ss='italiano</a> femminile';
tt='italiano</a> maschile';
nomipotenzialmentemaschili=nomiverificabili;

# %%
#stampa solo nomi femminili
print("UPDATE YOURTABLE SET SESSO ='F' WHERE NOME IN ('EVA' ");
for x in nomiverificabili:
  
  for url in search('Nome ' +x, stop=6):
     if 'wikipedia' in url:
       req = requests.get(url).text
       if ss in req:
         print(", '"+x+"'");
         nomipotenzialmentemaschili.remove(x);
         #print(req)  
         break;
     #else:
       #print(req);  
print(") ")
# Out:
# , 'CELINIA'
# , 'EURIDICE'
# , 'ERSILIA'
# , 'SALOMÈ'
# , 'POLISSENA'
# , 'ZAIRA'
# , 'ADELAIDE'
# , 'ISOTTA'
# , 'SEFORA'
# , 'BELINA'
# , 'CUNEGONDA'
# , 'ADRIA'
# , 'DORA'
# , 'LILIANA'
# , 'DESDEMONA'
# , 'TECLA'
# , 'NUCCIA'
# , 'OSANNA'
# , 'SCOLASTICA'
# , 'DALIDA'
# , 'ILENIA'
# , 'FLORA'
# , 'IDA'
# , 'ENRICA'
# , 'VIRGINIA'
# , 'ORNELLA'
# , 'ARMIDA'
# , 'LICIA'
# , 'EDDA'
# , 'CINZIA'
# , 'LIA'
# , 'ORSOLA'
# , 'APOLLINA'
# , 'CLEOPATRA'
# , 'PERLA'
# , 'BERENICE'
# , 'MASSIMA'
# , 'AIDA'
# , 'ANTEA'
# , 'ABBONDANZA'
# , 'ILEANA'
# , 'ARTEMISA'
# , 'LUISA'
# , 'DINA'
# , 'AMELIA'
# , 'EDITTA'
# , 'ROSAMUNDA'
# , 'INES'
# , 'GIUDITTA'
# , 'ARIANNA'
# , 'ESTELLA'
# , 'EULALIA'
# , 'LEDA'
# , 'CLAUDIA'
# , 'DELFINA'
# , 'ILDA'
# , 'ELISABETTA'
# , 'NOVELLA'
# , 'MARA'
# , 'IMELDA'
# , 'EDVIGE'
# , 'GIULIANA'
# , 'SOFIA'
# , 'PRISCILLA'
# , 'ROBERTA'
# , 'LAVINIA'
# , 'ANNUNZIATA'
# , 'ANNABELLA'
# , 'LUCIANA'
# , 'BENEDETTA'
# , 'DONATELLA'
# , 'AZZURRA'
# , 'ANASTASIA'
# , 'ZOE'
# , 'FEDORA'
# , 'CORDELIA'
# , 'ELIDE'
# , 'DOROTEA'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-172e3c5b85df> in <module>()
#       2 #test stampa solo nomi femminili
#       3 for x in nomiverificabili:
# ----> 4   for url in search('Nome ' +x, stop=6):
#       5      if 'wikipedia' in url:
#       6        req = requests.get(url).text
#
# /usr/local/lib/python3.7/dist-packages/googlesearch/__init__.py in search(query, tld, lang, tbs, safe, num, start, stop, domains, pause, tpe, country, extra_params, user_agent)
#     307         # Sleep between requests.
#     308         # Keeps Google from banning you for making too many requests.
# --> 309         time.sleep(pause)
#     310
#     311         # Request the Google Search results page.
#
# KeyboardInterrupt:

# %%
#test stampa solo nomi maschili
print("UPDATE YOURTABLE SET SESSO ='M' WHERE NOME IN ('ADAMO' ");
for x in nomiverificabili:
  for url in search('Nome ' +x, stop=6):
     if 'wikipedia' in url:
       req = requests.get(url).text
       if tt in req:
         print(", '"+x+"'");
         #print(req)  
         break;
print(") ")
