# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandro-lion/LearningPython/blob/main/Script_costruzione_where_clause_nome_per_update_informazione_sesso_su_db_anagrafiche_con_ricerca_su_wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import librerie

# %%
from googlesearch import search
import requests

# %% [markdown]
# # Valori di esempio

# %%
nomiverificabili=['IONA',
'LIBORIA',
'BARNABA',
'BRANCALEONE',
'CELINIA',
'BABILA',
'NARSETE',
'GIOSUELE',
'DEODATA',
'UMILE',
'DODA',
'EURIDICE',
'ERSILIA',
'CUZIA',
'ELITA',
'ASELLA',
'INNOCENTE',
'VENUSTA',
'CLEOFE',
'AMABILE',
'VALTENA',
'ELIMENA',
'SALOMÈ',
'GEDEONE',
'DANTE',
'GEREMIA',
'CARONTE',
'AGENORE',
'PARIDE',
'IACOPONE',
'POLISSENA',
'ELVIA',
'GIONATA',
'TICONE',
'ZAIRA',
'ASTRID',
'BICE',
'MARANA',
'ABELE',
'COSMA',
'FEDELE',
'LUIGIA',
'ADELAIDE',
'AMATORE',
'ZENOBIA',
'ZACCARIA',
'IDEA',
'ARIELE',
'NICLA',
'VIRONE',
'ERENIA',
'ERACLIDE',
'ISOTTA',
'SEFORA',
'TAZIANA',
'BELINA',
'NICARETE',
'ERACLA',
'VITALE',
'DIONIGI',
'VALENTE',
'NEREA',
'SECONDINA',
'CUNEGONDA',
'MELCHIADE',
'TEOGENE',
'AMOS',
'TRASEA',
'LEONE',
'ADRIA',
'ALCIBIADE',
'DORA',
'LILIANA',
'DESDEMONA',
'OSCAR',
'ZELINDA',
'TECLA',
'NICEA',
'CORA',
'BAMBINA',
'ISIDORA',
'NUCCIA',
'SAPIENTE',
'OMAR',
'PERICLE',
'MANUELE',
'QUITERIA',
'OSANNA',
'GIOELE',
'DELINDA',
'MENNONE',
'GENTILE',
'MAMANTE',
'GOLIA',
'ONORINA',
'SCOLASTICA',
'DONNA',
'ASTIANATTE',
'DALIDA',
'AMILCARE',
'VITTORE',
'ODDONE',
'BONAVITA',
'ILENIA',
'DIAMANTE',
'FLORA',
'URIELE',
'RINA',
'IDA',
'POLLIONE',
'VERIANA',
'DAVIDE',
'ENRICA',
'VIRGINIA',
'ORNELLA',
'ARMIDA',
'BALDASSARRE',
'GASPARE',
'PAOLA',
'AUDACE',
'LICIA',
'PRISCA',
'EDDA',
'LORIS',
'GAUDENZIA',
'CINZIA',
'CELESTE',
'TELICA',
'GUNDELINDA',
'COLOMBA',
'AMORE',
'MORGANA',
'LIA',
'ORSOLA',
'LUCREZIA',
'FABIANA',
'EGEA',
'EGIZIA',
'APOLLINA',
'CLEOPATRA',
'PERLA',
'BERENICE',
'MASSIMA',
'GLENDA',
'AIDA',
'ANTEA',
'GENESIA',
'VALTER',
'ERCOLE',
'MACARIA',
'SALOMONE',
'AMINA',
'BATTISTA',
'ABBONDANZA',
'LELIA',
'ARABELLA',
'ZENONE',
'RUFINA',
'ILEANA',
'AZELIA',
'ARTEMISA',
'LUISA',
'BARTOLOMEA',
'VIDONE',
'ENEA',
'ANNA',
'DINA',
'AMELIA',
'BORIS',
'ACHILLE',
'APPIA',
'EDITTA',
'ILVA',
'SANTINA',
'ROSAMUNDA',
'GIULIA',
'GIAMBATTISTA',
'INES',
'GIUDITTA',
'LORETTA',
'SAMANTA',
'CALPURNIA',
'ARIANNA',
'ESTELLA',
'GODEBERTA',
'EULALIA',
'MANUELA',
'SOSTENE',
'BEATA',
'VISSIA',
'LEDA',
'GASTONE',
'ANATOLIA',
'ROMOLA',
'ATHOS',
'DAMOCLE',
'CLAUDIA',
'DELFINA',
'ILDA',
'ELISABETTA',
'MELITINA',
'AMAURI',
'CLEMENZIA',
'ZANITA',
'NOVELLA',
'MELANIA',
'MARA',
'MARITA',
'IMELDA',
'QUARTILLA',
'FLAMINIA',
'EDVIGE',
'GIULIANA',
'SOFIA',
'PRISCILLA',
'EMILIA',
'DURANTE',
'ROBERTA',
'LAVINIA',
'VILIANA',
'ANNUNZIATA',
'CALOGERA',
'GIANLUIGI',
'ANNABELLA',
'SERAPIONE',
'GIUSEPPE',
'LUCIANA',
'BENEDETTA',
'FAUSTA',
'DONATELLA',
'PATRIZIA',
'CAMILLA',
'PLACIDA',
'AZZURRA',
'ARCHIMEDE',
'ANASTASIA',
'ZOE',
'FEDORA',
'ARISTIDE',
'NEIVA',
'ELISEA',
'CORDELIA',
'ELAIDE',
'ELIDE',
'ARMAND',
'NINA',
'DOROTEA',
'MARUTA',
'SABRINA',
'BONAVENTURA',
'PIERLUIGI',
'DEMETRIA',
'ZARINA',
'IMMACOLATA',
'AGAPE',
'FRANCA',
'CRISTINA',
'IVANOE',
'DANIELA',
'AVE',
'TIRONE',
'NICOLA',
'IVETTA',
'CORINNA',
'ALCINA',
'AGAMENNONE',
'GIOVANNI',
'MARIANNA',
'CATERINA',
'CHIARA',
'BASSILLA',
'BRIGIDA',
'GILIOLA',
'ANDREA',
'MADDALENA',
'LEONIDA',
'BONAGIUNTA',
'RAFFAELE',
'GIANMARIA',
'BENIGNA',
'MIRTA',
'SVEVA',
'SOCRATE',
'FELICITA',
'MONITORE',
'LORENA',
'VENERANDA',
'ITALIA',
'CRISTIANA',
'NADIA',
'CORNELIA',
'ELETTRA',
'MARINA',
'ILIA',
'ISABELLA',
'GRETA',
'OTILIA',
'GABRIELE',
'BRUNILDE',
'GERTRUDE',
'LUCILLA',
'ALDA',
'BASILIA',
'VERA',
'ELVIRA',
'GIANBATTISTA',
'ADINA',
'AGNESE',
'ADONE',
'FLORINA',
'LORENZA',
'EBE',
'DIONISIA',
'SANTE',
'CARLA',
'ALBINA',
'GHITA',
'OFELIA',
'ISIDE',
'TARSILLA',
'AURORA',
'CATENA',
'TESIFONTE',
'CLOE',
'DONATA',
'ELISA',
'DRUINA',
'MARTA',
'ARATONE',
'REBECCA',
'DEBORA',
'GIOSUÈ',
'GIOACCHINA',
'EGLE',
'SALVATORE',
'CASSIOPEA',
'ELIA',
'GIACOBBE',
'NIVES',
'ROSALINDA',
'ALBERTA',
'ARONNE',
'ROSALIA',
'SELENE',
'EUFEMIA',
'GIOVANNA',
'PLATONE',
'ADRIANA',
'LUNA',
'BATILDA',
'SIMONETTA',
'APOLLINARE',
'DIONE',
'BRIGITTA',
'LUIGI',
'LINDA',
'TEA',
'NORMA',
'ERMETE',
'SOLANGE',
'OLIVIERA',
'PAMELA',
'LEONTINA',
'SIMEONE',
'GIORGIA',
'GISELLA',
'EMILIANA',
'GIONA',
'VILMA',
'ALTEA',
'EUCLIDE',
'DOMENICA',
'MARZIA',
'EZECHIELE',
'TURI',
'FIAMMETTA',
'ADRIONE',
'SEMIRAMIDE',
'CLEMENTE',
'ALESSIA',
'UGUCCIONE',
'ADELE',
'VIVIANA',
'ALCESTE',
'RENATA',
'LODOVICA',
'GERMANA',
'ORSOLINA',
'TULLIA',
'ESAÙ',
'AMONE',
'SIDONIA',
'EMANUELE',
'TOSCA',
'SENOFONTE',
'ORCHIDEA',
'ADALBERTA',
'MILENA',
'SARA',
'ISAIA',
'FATIMA',
'GIOVE',
'GODIVA',
'ULFA',
'MARINELLA',
'MARETA',
'LAURA',
'UGOLINA',
'IRENE',
'FOSCA',
'CAROLINA',
'CASILDA',
'APOLLONIA',
'ALMA',
'DAMIANA',
'MATILDE',
'ZENA',
'FLAVIA',
'GIUDA',
'DELIZIA',
'ELEONORA',
'ROMINA',
'GENEROSA',
'WALTER',
'AIMONE',
'SAMUELE',
'CARMINE',
'ANGELA',
'NAPOLEONE',
'DIOGENE',
'NILDE',
'ROSMUNDA',
'ERMES',
'ELIANA',
'VANESSA',
'VANNA',
'NOÈ',
'CARLOTTA',
'NATALIA',
'GONZAGA',
'IOLANDA',
'ANTONELLA',
'CLARA',
'SUSANNA',
'CARMELA',
'TERESA',
'EMANUELA',
'GRAZIA',
'DANIELE',
'VANDA',
'LEONILDA',
'TEMISTOCLE',
'ADELINA',
'DARIA',
'GUENDALINA',
'LUCA',
'TEODORA',
'FIORENZA',
'AMATA',
'AGRIPPA',
'CIRILLA',
'LIDANIA',
'IRMINA',
'BIBIANA',
'COINTA',
'MATTIA',
'VIOLA',
'ERMINIA',
'SAMONA',
'NOEMI',
'BARSABA',
'VENTURA',
'FULVIA',
'ONESTA',
'DILETTA',
'IVONE',
'MINERVINA',
'GIANLUCA',
'DOLORES',
'TEODATA',
'ARISTOFANE',
'PANTALEONE',
'DIANORA',
'DIANA',
'ADELASIA',
'LIVIANA',
'SEVERA',
'ROSITA',
'LISA',
'PROSERPINA',
'GUENDA',
'AUSILIA',
'ARIS',
'MENODORA',
'ULISSE',
'NUNZIATA',
'CASIMIRA',
'COSTANZA',
'FILOMENA',
'ADELCHI',
'MAIDA',
'ONDINA',
'GAIA',
'DIODATA',
'EVANGELINA',
'CARINA',
'ROSA',
'EUSEBIA',
'GIGLIOLA',
'GALATEA',
'SILVANA',
'AUSILIATRICE',
'ALFONSA',
'SERAFINA',
'AMINTORE',
'VERDIANA',
'FIORELLA',
'FIORE',
'LUCE',
'PALMIRA',
'NINFA',
'ISCHIRIONE',
'LARA',
'LIBERATORE',
'COSTANTE',
'PALLADIA',
'ISA',
'DALILA',
'ERMENEGILDA',
'SIBILLA',
'AURELIA',
'NESTORE',
'GRAZIELLA',
'TOBIA',
'ATANASIA',
'ANNIBALE',
'NATALINA',
'FLORIANA',
'NORINA',
'PELAGIA',
'ELOISA',
'OTTONE',
'SANDRA',
'CRONIDA',
'DAFNE',
'LEONIA',
'LUCIA',
'QUIETA',
'VERIDIANA',
'VERONICA',
'SOLOCONE',
'PROSPERA',
'TIZIANA',
'CAMELIA',
'GELSOMINA',
'LIANA',
'DEGNA',
'ZABINA',
'ASSUNTA',
'ALICE',
'SABINA',
'ARGELIA',
'MAURA',
'ELSA',
'RICCARDA',
'MORENA',
'PENELOPE',
'MERCEDE',
'AZA',
'MINERVA',
'MARTINA',
'AGATA',
'DEANNA',
'ANTONIA',
'INNOCENZA',
'GINEVRA',
'MARIA',
'LUDOVICA',
'NATALE',
'IPPOCRATE',
'AGOSTINA',
'ARISTIONE',
'ULIVA',
'MOSÈ',
'ANDROMEDA',
'MARISA',
'CRESCENTE',
'IGINIA',
'AIACE',
'ALESSANDRA',
'ZAMA',
'DEMOSTENE',
'GIOBBE',
'MIRANDA',
'GIACINTA',
'SOAVE',
'EVELINA',
];

# %% [markdown]
# # Inizializzazione array con i valori effettivi da elaborare

# %%
nomiverificabili=['IONA','LIBORIA','BARNABA','BRANCALEONE','BABILA','NARSETE','GIOSUELE','DEODATA','UMILE','DODA',
'CUZIA','ELITA','ASELLA','INNOCENTE','VENUSTA','CLEOFE','AMABILE','ELIMENA','VALTENA','GEDEONE','DANTE','GEREMIA',
'AGENORE','CARONTE','PARIDE','IACOPONE','ELVIA','GIONATA','TICONE','ASTRID','BICE','MARANA','ABELE','COSMA','FEDELE',
'LUIGIA','AMATORE','ZENOBIA','ZACCARIA','IDEA','NICLA','ARIELE','VIRONE','ERENIA','ERACLIDE','TAZIANA','NICARETE',
'VITALE','ERACLA','DIONIGI','VALENTE','NEREA','SECONDINA','MELCHIADE','TEOGENE','AMOS','TRASEA','LEONE','ALCIBIADE','ZELINDA','OSCAR',
'BAMBINA','CORA','NICEA','ISIDORA','SAPIENTE','OMAR','QUITERIA','PERICLE','MANUELE','GIOELE','DELINDA','MENNONE','GENTILE','MAMANTE',
'DONNA','ONORINA','GOLIA','ASTIANATTE','AMILCARE','VITTORE','ODDONE','BONAVITA','URIELE','DIAMANTE','RINA','POLLIONE','DAVIDE',
'VERIANA',
'BALDASSARRE',
'GASPARE',
'PAOLA',
'PRISCA',
'LORIS',
'AUDACE',
'GAUDENZIA',
'CELESTE',
'TELICA',
'GUNDELINDA',
'COLOMBA',
'AMORE',
'LUCREZIA',
'MORGANA',
'FABIANA',
'EGIZIA',
'EGEA',
'GLENDA',
'GENESIA',
'AMINA',
'VALTER',
'MACARIA',
'SALOMONE',
'ERCOLE',
'BATTISTA',
'ARABELLA',
'ZENONE',
'LELIA',
'AZELIA',
'RUFINA',
'BARTOLOMEA',
'VIDONE',
'ANNA',
'ENEA',
'BORIS',
'APPIA',
'ILVA',
'ACHILLE',
'SANTINA',
'GIULIA',
'GIAMBATTISTA',
'LORETTA',
'SAMANTA',
'GODEBERTA',
'CALPURNIA',
'MANUELA',
'SOSTENE',
'VISSIA',
'BEATA',
'ANATOLIA',
'GASTONE',
'ATHOS',
'ROMOLA',
'DAMOCLE',
'MELITINA',
'AMAURI',
'ZANITA',
'CLEMENZIA',
'MELANIA',
'MARITA',
'FLAMINIA',
'QUARTILLA',
'EMILIA',
'VILIANA',
'DURANTE',
'CALOGERA',
'GIANLUIGI',
'GIUSEPPE',
'SERAPIONE',
'FAUSTA',
'CAMILLA',
'PLACIDA',
'ARCHIMEDE',
'PATRIZIA',
'NEIVA',
'ARISTIDE',
'ELISEA',
'ELAIDE',
'ARMAND',
'NINA',
'MARUTA',
'SABRINA',
'BONAVENTURA',
'DEMETRIA',
'PIERLUIGI',
'AGAPE',
'IMMACOLATA',
'ZARINA',
'DANIELA',
'IVANOE',
'FRANCA',
'CRISTINA',
'AVE',
'TIRONE',
'IVETTA',
'NICOLA',
'CORINNA',
'GIOVANNI',
'AGAMENNONE',
'CATERINA',
'ALCINA',
'MARIANNA',
'BRIGIDA',
'BASSILLA',
'CHIARA',
'MADDALENA',
'GILIOLA',
'ANDREA',
'LEONIDA',
'BONAGIUNTA',
'RAFFAELE',
'GIANMARIA',
'BENIGNA',
'MIRTA',
'SOCRATE',
'SVEVA',
'LORENA',
'FELICITA',
'MONITORE',
'ITALIA',
'VENERANDA',
'CRISTIANA',
'CORNELIA',
'ELETTRA',
'NADIA',
'ISABELLA',
'MARINA',
'ILIA',
'OTILIA',
'GRETA',
'GABRIELE',
'BRUNILDE',
'ALDA',
'GERTRUDE',
'LUCILLA',
'VERA',
'BASILIA',
'GIANBATTISTA',
'ELVIRA',
'FLORINA',
'ADINA',
'AGNESE',
'LORENZA',
'ADONE',
'DIONISIA',
'EBE',
'CARLA',
'SANTE',
'ALBINA',
'ISIDE',
'GHITA',
'OFELIA',
'CATENA',
'TARSILLA',
'AURORA',
'TESIFONTE',
'CLOE',
'DONATA',
'ELISA',
'DRUINA',
'ARATONE',
'MARTA',
'GIOSUÈ',
'DEBORA',
'REBECCA',
'EGLE',
'GIOACCHINA',
'SALVATORE',
'CASSIOPEA',
'GIACOBBE',
'NIVES',
'ELIA',
'ALBERTA',
'ARONNE',
'ROSALINDA',
'ROSALIA',
'PLATONE',
'SELENE',
'GIOVANNA',
'EUFEMIA',
'ADRIANA',
'LUNA',
'APOLLINARE',
'SIMONETTA',
'BATILDA',
'DIONE',
'BRIGITTA',
'LUIGI',
'LINDA',
'TEA',
'ERMETE',
'NORMA',
'SOLANGE',
'OLIVIERA',
'PAMELA',
'LEONTINA',
'SIMEONE',
'GIORGIA',
'GISELLA',
'EMILIANA',
'GIONA',
'VILMA',
'ALTEA',
'EUCLIDE',
'DOMENICA',
'MARZIA',
'EZECHIELE',
'TURI',
'FIAMMETTA',
'ADRIONE',
'SEMIRAMIDE',
'CLEMENTE',
'ALESSIA',
'UGUCCIONE',
'ADELE',
'VIVIANA',
'ALCESTE',
'RENATA',
'LODOVICA',
'GERMANA',
'ORSOLINA',
'TULLIA',
'ESAÙ',
'AMONE',
'SIDONIA',
'EMANUELE',
'TOSCA',
'SENOFONTE',
'ORCHIDEA',
'ADALBERTA',
'MILENA',
'SARA',
'ISAIA',
'FATIMA',
'GIOVE',
'GODIVA',
'ULFA',
'MARINELLA',
'MARETA',
'LAURA',
'UGOLINA',
'IRENE',
'FOSCA',
'CAROLINA',
'CASILDA',
'APOLLONIA',
'ALMA',
'DAMIANA',
'MATILDE',
'ZENA',
'FLAVIA',
'GIUDA',
'DELIZIA',
'ELEONORA',
'ROMINA',
'GENEROSA',
'WALTER',
'AIMONE',
'SAMUELE',
'CARMINE',
'ANGELA',
'NAPOLEONE',
'DIOGENE',
'NILDE',
'ROSMUNDA',
'ERMES',
'ELIANA',
'VANESSA',
'VANNA',
'NOÈ',
'CARLOTTA',
'NATALIA',
'GONZAGA',
'IOLANDA',
'ANTONELLA',
'CLARA',
'SUSANNA',
'CARMELA',
'TERESA',
'EMANUELA',
'GRAZIA',
'DANIELE',
'VANDA',
'LEONILDA',
'TEMISTOCLE',
'ADELINA',
'DARIA',
'GUENDALINA',
'LUCA',
'TEODORA',
'FIORENZA',
'AMATA',
'AGRIPPA',
'CIRILLA',
'LIDANIA',
'IRMINA',
'BIBIANA',
'COINTA',
'MATTIA',
'VIOLA',
'ERMINIA',
'SAMONA',
'BARSABA',
'NOEMI',
'VENTURA',
'FULVIA',
'DILETTA',
'ONESTA',
'IVONE',
'GIANLUCA',
'MINERVINA',
'ARISTOFANE',
'DOLORES',
'TEODATA',
'PANTALEONE',
'DIANORA',
'DIANA',
'ADELASIA',
'LIVIANA',
'SEVERA',
'ROSITA',
'LISA',
'PROSERPINA',
'GUENDA',
'AUSILIA',
'ARIS',
'MENODORA',
'ULISSE',
'NUNZIATA',
'CASIMIRA',
'FILOMENA',
'COSTANZA',
'ADELCHI',
'MAIDA',
'ONDINA',
'GAIA',
'DIODATA',
'EVANGELINA',
'ROSA',
'CARINA',
'GIGLIOLA',
'EUSEBIA',
'GALATEA',
'SILVANA',
'AUSILIATRICE',
'ALFONSA',
'SERAFINA',
'AMINTORE',
'VERDIANA',
'FIORELLA',
'FIORE',
'LUCE',
'PALMIRA',
'NINFA',
'ISCHIRIONE',
'LARA',
'LIBERATORE',
'COSTANTE',
'PALLADIA',
'SIBILLA',
'ERMENEGILDA',
'DALILA',
'AURELIA',
'ISA',
'NESTORE',
'GRAZIELLA',
'TOBIA',
'ATANASIA',
'ANNIBALE',
'NATALINA',
'FLORIANA',
'NORINA',
'PELAGIA',
'ELOISA',
'OTTONE',
'SANDRA',
'CRONIDA',
'DAFNE',
'LEONIA',
'LUCIA',
'QUIETA',
'VERIDIANA',
'VERONICA',
'SOLOCONE',
'PROSPERA',
'TIZIANA',
'CAMELIA',
'GELSOMINA',
'LIANA',
'DEGNA',
'ZABINA',
'ASSUNTA',
'ALICE',
'SABINA',
'ARGELIA',
'MAURA',
'ELSA',
'RICCARDA',
'MORENA',
'PENELOPE',
'MERCEDE',
'AZA',
'MINERVA',
'MARTINA',
'AGATA',
'DEANNA',
'ANTONIA',
'INNOCENZA',
'GINEVRA',
'MARIA',
'LUDOVICA',
'NATALE',
'IPPOCRATE',
'AGOSTINA',
'ARISTIONE',
'ULIVA',
'MOSÈ',
'ANDROMEDA',
'MARISA',
'CRESCENTE',
'IGINIA',
'AIACE',
'ALESSANDRA',
'ZAMA',
'DEMOSTENE',
'GIOBBE',
'MIRANDA',
'GIACINTA',
'SOAVE',
'EVELINA' ]

# %%
#Stringhe di identificazione ed inizializzazione array per secondo ciclo
ss='italiano</a> femminile';
tt='italiano</a> maschile';
nomipotenzialmentemaschili=['adamo'];
nomipotenzialmentemaschili=nomiverificabili;

# %% [markdown]
# # Primo ciclo, costruzione where per nomi femminili

# %%
#PRIMO CICLO
#stampa solo nomi femminili
print("UPDATE YOURTABLE SET SESSO ='F' WHERE NOME IN ('EVA' ");
for x in nomiverificabili:
  
  for url in search('Nome ' +x, stop=6):
     if 'wikipedia' in url:
       req = requests.get(url).text
       if ss in req:
         print(", '"+x+"'");
         nomipotenzialmentemaschili.remove(x);
         #print(req)  
         break;
     #else:
       #print(req);  
print(") ")
# Out:
# UPDATE YOURTABLE SET SESSO ='F' WHERE NOME IN ('EVA'

# %% [markdown]
# # Secondo ciclo, costruzione where per nomi maschili

# %%
#test stampa solo nomi maschili
print("UPDATE YOURTABLE SET SESSO ='M' WHERE NOME IN ('ADAMO' ");
for x in nomiverificabili:
  for url in search('Nome ' +x, stop=6):
     if 'wikipedia' in url:
       req = requests.get(url).text
       if tt in req:
         print(", '"+x+"'");
         #print(req)  
         break;
print(") ")
